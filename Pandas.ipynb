# %% [markdown]
# <a href="https://colab.research.google.com/github/pratyasha7/Infosys_BudgetWise-AI-Expense-Forecasting-Tool/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Series Object Multi-dimensional: Data-frame

# %%
import pandas as pd
s1=pd.Series([1,2,3,4,5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Changing index Positions

# %%
import pandas as pd
pd.Series({'a': 10, 'b': 20, 'c': 30}, index=['b', 'c', 'd', 'a'])
# Out:
# b    20.0
# c    30.0
# d     NaN
# a    10.0
# dtype: float64

# %% [markdown]
# Extracting Individual Element

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6, 7, 8, 9])
s1[3]
# Out:
# np.int64(4)

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6, 7, 8, 9])
s1[:4]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6, 7, 8, 9])
s1[-3:]
# Out:
# 6    7
# 7    8
# 8    9
# dtype: int64

# %% [markdown]
# Basic Math Operations on Series

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6, 7, 8, 9])
s2 = pd.Series([10, 20, 30, 40, 50, 60, 70, 80, 90])
s1 + s2
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# 6    77
# 7    88
# 8    99
# dtype: int64

# %%
s1 + 5
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# 5    11
# 6    12
# 7    13
# 8    14
# dtype: int64

# %% [markdown]
# DataFrame Creation and Inspection

# %%
pd.DataFrame({ "Name": ['Bob', 'Sam', 'Anne'], "Marks": [76, 25, 92] })
# Out:
#    Name  Marks
# 0   Bob     76
# 1   Sam     25
# 2  Anne     92

# %%
ds = pd.read_csv('iris.data.csv')
ds.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ds.shape
# Out:
# (150, 5)

# %%
ds.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Indexing and Slicing DataFrames

# %%
ds.iloc[0:3, 0:2]
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2

# %%
ds.iloc[30:40, 3:]
# Out:
#     PetalWidthCm      Species
# 30           0.2  Iris-setosa
# 31           0.4  Iris-setosa
# 32           0.1  Iris-setosa
# 33           0.2  Iris-setosa
# 34           0.1  Iris-setosa
# 35           0.2  Iris-setosa
# 36           0.2  Iris-setosa
# 37           0.1  Iris-setosa
# 38           0.2  Iris-setosa
# 39           0.2  Iris-setosa

# %%
ds.loc[0:3, ("SepalLengthCm", "PetalLengthCm")]
# Out:
#    SepalLengthCm  PetalLengthCm
# 0            5.1            1.4
# 1            4.9            1.4
# 2            4.7            1.3
# 3            4.6            1.5

# %% [markdown]
# Dropping Rows and Columns in Pandas

# %%
import pandas as pd
ds = pd.read_csv('iris.data.csv')
ds.drop('SepalLengthCm', axis=1)
# Out:
#      SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0             3.5            1.4           0.2     Iris-setosa
# 1             3.0            1.4           0.2     Iris-setosa
# 2             3.2            1.3           0.2     Iris-setosa
# 3             3.1            1.5           0.2     Iris-setosa
# 4             3.6            1.4           0.2     Iris-setosa
# ..            ...            ...           ...             ...
# 145           3.0            5.2           2.3  Iris-virginica
# 146           2.5            5.0           1.9  Iris-virginica
# 147           3.0            5.2           2.0  Iris-virginica
# 148           3.4            5.4           2.3  Iris-virginica
# 149           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
ds.drop([1, 2, 3], axis=0)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
ds.mean(numeric_only=True)
# Out:
# SepalLengthCm    5.843333
# SepalWidthCm     3.054000
# PetalLengthCm    3.758667
# PetalWidthCm     1.198667
# dtype: float64

# %%
ds.median(numeric_only=True)
# Out:
# SepalLengthCm    5.80
# SepalWidthCm     3.00
# PetalLengthCm    4.35
# PetalWidthCm     1.30
# dtype: float64

# %%
ds.min()
# Out:
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
ds.max()
# Out:
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object
